# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib  inline

# %%
# 读写数据文件
data = pd.read_csv('C25.csv')

# %%
ax = plt.subplots(figsize=(20, 10))#调整画布大小
ax = sns.heatmap(data.T)#画热力图
